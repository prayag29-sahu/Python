# %%
import pandas as pd

df = pd.read_csv("complete_student_analysis_dataset.csv")
# print(df)

attendance_by_grade = df['math_original'].mean()
print(attendance_by_grade)
attendance_by_grade = df['math_original'].mode()
print(attendance_by_grade)
# Out:
# 73.44219999999999
# 0    71.49
# 1    80.42
# Name: math_original, dtype: float64
# 73.1
# 13.622571775468014
# 35.7
# 102.78
