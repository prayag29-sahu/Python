# %%
import pandas as pd

df = pd.read_csv("complete_student_analysis_dataset.csv")
# print(df)

attendance_by_grade = df .groupby('grade')['attendance'].mean()
print("Average Attendance by Grade Level:")
print(attendance_by_grade)
# Out:
# Average Attendance by Grade Level:
# grade
# A    91.000000
# B    84.939394
# C    82.957447
# D    89.875000
# Name: attendance, dtype: float64
